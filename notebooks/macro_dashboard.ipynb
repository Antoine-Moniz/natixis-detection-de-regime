# %% [markdown]
# # Tableau de bord extraction données macro
#
# Ce notebook charge le panel `macro_panel.parquet` et trace quelques indicateurs clefs pour validation rapide.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

panel_path = Path("..") / "data" / "processed" / "macro_panel.parquet"
panel = pd.read_parquet(panel_path)
panel.tail()
# Out:
#             ecb_main_refi  it_manufacturing_confidence  fr_manufacturing_pmi  \
# date
# 2025-11-10            NaN                          NaN                   NaN
# 2025-11-11            NaN                          NaN                   NaN
# 2025-11-12            NaN                          NaN                   NaN
# 2025-11-13            NaN                          NaN                   NaN
# 2025-11-14            NaN                          NaN                   NaN
#
#             de_ifo_business_climate  jp_jobless_rate  us_fed_funds_upper  \
# date
# 2025-11-10                      NaN              NaN                 4.0
# 2025-11-11                      NaN              NaN                 4.0
# 2025-11-12                      NaN              NaN                 4.0
# 2025-11-13                      NaN              NaN                 4.0
# 2025-11-14                      NaN              NaN                 4.0
#
#             us_michigan_sentiment  ea_economic_sentiment  fr_cpi_yoy  \
# date
# 2025-11-10                    NaN                    NaN         NaN
# 2025-11-11                    NaN                    NaN         NaN
# 2025-11-12                    NaN                    NaN         NaN
# 2025-11-13                    NaN                    NaN         NaN
# 2025-11-14                    NaN                    NaN         NaN
#
#             us_nfp_change  jp_industrial_production_mom  us_initial_claims  \
# date
# 2025-11-10            NaN                           NaN                NaN
# 2025-11-11            NaN                           NaN                NaN
# 2025-11-12            NaN                           NaN                NaN
# 2025-11-13            NaN                           NaN                NaN
# 2025-11-14            NaN                           NaN                NaN
#
#             us_cpi_mom  us_ism_manufacturing  ea_cpi_yoy  us_gdp_qoq  \
# date
# 2025-11-10         NaN                   NaN         NaN         NaN
# 2025-11-11         NaN                   NaN         NaN         NaN
# 2025-11-12         NaN                   NaN         NaN         NaN
# 2025-11-13         NaN                   NaN         NaN         NaN
# 2025-11-14         NaN                   NaN         NaN         NaN
#
#             de_zew_expectations  jp_gdp_qoq
# date
# 2025-11-10                  NaN         NaN
# 2025-11-11                  NaN         NaN
# 2025-11-12                  NaN         NaN
# 2025-11-13                  NaN         NaN
# 2025-11-14                  NaN         NaN

# %%
selected_cols = [
    col for col in panel.columns[:6]
]

fig, axes = plt.subplots(len(selected_cols), 1, figsize=(10, 2 * len(selected_cols)), sharex=True)
for ax, col in zip(axes, selected_cols):
    panel[col].plot(ax=ax, title=col)
    ax.grid(True, alpha=0.3)
fig.tight_layout()
fig

# %%
for col in panel.columns:
    non_null = panel[col].dropna()
    if non_null.empty:
        print(f"{col}: aucune observation")
    else:
        print(f"{col}: {non_null.index.min().date()} -> {non_null.index.max().date()} ({len(non_null)} points)")
# Out:
# ecb_main_refi: 1999-01-29 -> 2025-10-31 (322 points)
# it_manufacturing_confidence: 2000-02-29 -> 2025-10-31 (308 points)
# fr_manufacturing_pmi: 2022-12-31 -> 2025-10-31 (35 points)
# de_ifo_business_climate: 2005-02-28 -> 2025-10-31 (249 points)
# jp_jobless_rate: 1953-02-28 -> 2025-09-30 (872 points)
# us_fed_funds_upper: 1971-01-04 -> 2025-11-14 (14177 points)
# us_michigan_sentiment: 1978-02-28 -> 2025-10-31 (573 points)
# ea_economic_sentiment: 1985-02-28 -> 2025-10-31 (489 points)
# fr_cpi_yoy: 1958-03-31 -> 2025-10-31 (812 points)
# us_nfp_change: 1940-02-29 -> 2025-08-31 (1027 points)
# jp_industrial_production_mom: 1978-03-31 -> 2025-09-30 (571 points)
# us_initial_claims: 1967-01-13 -> 2025-09-19 (3063 points)
# us_cpi_mom: 1947-03-31 -> 2025-09-30 (943 points)
# us_ism_manufacturing: 1948-02-29 -> 2025-10-31 (933 points)
# ea_cpi_yoy: 1997-02-28 -> 2025-10-31 (345 points)
# us_gdp_qoq: 1947-09-30 -> 2025-06-30 (312 points)
# de_zew_expectations: 1992-01-31 -> 2025-10-31 (406 points)
# jp_gdp_qoq: 1994-09-30 -> 2025-06-30 (124 points)

# %%
panel.describe().T
# Out:
#                                 count        mean         std       min  \
# ecb_main_refi                   322.0    1.744410    1.576260      0.00
# it_manufacturing_confidence     308.0   90.868182    7.261879     63.30
# fr_manufacturing_pmi             35.0   46.051429    2.377761     41.90
# de_ifo_business_climate         249.0   95.520884    6.146377     75.00
# jp_jobless_rate                 872.0    2.715023    1.179228      1.00
# us_fed_funds_upper            14177.0    4.890749    3.766675      0.25
# us_michigan_sentiment           573.0   84.252356   13.604793     50.00
# ea_economic_sentiment           489.0   99.877710   10.119312     58.50
# fr_cpi_yoy                      812.0    4.182759    3.829260     -0.70
# us_nfp_change                  1027.0  124.573515  705.959749 -20471.00
# jp_industrial_production_mom    571.0    0.090368    1.937061    -16.50
# us_initial_claims              3063.0  361.649037  239.645911    162.00
# us_cpi_mom                      943.0    0.286957    0.342108     -1.80
# us_ism_manufacturing            933.0   52.825402    7.138599     29.40
# ea_cpi_yoy                      345.0    2.051014    1.725394     -0.60
# us_gdp_qoq                      312.0    3.211538    4.527664    -28.00
# de_zew_expectations             406.0   21.387685   36.842478    -63.90
# jp_gdp_qoq                      124.0    0.204032    1.261332     -7.60
#
#                                   25%     50%      75%      max
# ecb_main_refi                   0.050    1.50    3.225     4.75
# it_manufacturing_confidence    87.625   91.60   94.725   105.70
# fr_manufacturing_pmi           44.350   45.80   48.150    50.50
# de_ifo_business_climate        90.800   97.70  100.100   105.00
# jp_jobless_rate                 2.000    2.50    3.400     5.50
# us_fed_funds_upper              1.750    5.13    6.750    20.00
# us_michigan_sentiment          73.400   88.20   94.400   112.00
# ea_economic_sentiment          94.700  100.00  106.400   119.60
# fr_cpi_yoy                      1.600    2.60    5.800    18.80
# us_nfp_change                  25.500  159.00  265.500  4631.00
# jp_industrial_production_mom   -0.750    0.20    1.200     6.80
# us_initial_claims             283.000  339.00  397.000  6137.00
# us_cpi_mom                      0.100    0.20    0.400     2.00
# us_ism_manufacturing           48.800   53.30   57.400    77.50
# ea_cpi_yoy                      1.100    1.90    2.400    10.60
# us_gdp_qoq                      1.275    3.10    5.025    34.90
# de_zew_expectations            -4.300   19.55   50.850    89.60
# jp_gdp_qoq                     -0.200    0.20    0.800     5.40
